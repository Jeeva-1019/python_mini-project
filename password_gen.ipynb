# %%
import secrets
import string

def generate_password():
    print("USER PASSWORD GENERATOR")

    # User input
    length = int(input("Enter password length (8–12): "))

    if length < 8 or length > 12:
        print("Password length must be between 8 and 12")
        return None

    upper = input("Include uppercase letters? (y/n): ").lower()
    lower = input("Include lowercase letters? (y/n): ").lower()
    digits = input("Include numbers? (y/n): ").lower()
    special = input("Include special characters? (y/n): ").lower()


    characters = ""

    if upper == "y":
        characters += string.ascii_uppercase
    if lower == "y":
        characters += string.ascii_lowercase
    if digits == "y":
        characters += string.digits
    if special == "y":
        characters += string.punctuation

    if characters == "":
        print("Please select at least one character type!")
        return None

    password = "".join(secrets.choice(characters) for _ in range(length))
    
    if upper == "y" and use_lower == "y" and digits == "y" and special == "y":
        print("Strong Password")
    elif ((upper == "y" and use_lower == "y" and digits == "y") or (upper == "y" and lower == "y" and special == "y") or
    (upper == "y" and digits == "y" and special == "y")):
        print("Medium Password")
    else:
        print("Weak Password")
    return password
     
pwd = generate_password()

print("Generated Password:", pwd)
# Out:
# USER PASSWORD GENERATOR
# Enter password length (8–12):  8
# Include uppercase letters? (y/n):  y
# Include lowercase letters? (y/n):  y
# Include numbers? (y/n):  y
# Include special characters? (y/n):  y
# Strong Password
# Generated Password: <9I`u_Xv
